# %%
# filling dummy data since this cell is parameterized
today_file = 'LMS_09-01-2023.csv'
processed_Date = '2025-06-27'
# Out:
# StatementMeta(, b86613a0-e2c1-49ff-b059-3c8981110075, 3, Finished, Available, Finished)

# %%
account_name = 'datalakefabriclms' # fill in your primary account name 
container_name = 'fabricproject' # fill in your container name 
relative_path = 'raw' # fill in your relative folder path 

adls_path = 'abfss://%s@%s.dfs.core.windows.net/%s' % (container_name, account_name, relative_path) 

print('Source storage account path is ', adls_path)
# Out:
# StatementMeta(, e61dfe50-8ee3-4d61-8633-a48646002e2f, 22, Finished, Available, Finished)
# Source storage account path is  abfss://fabricproject@datalakefabriclms.dfs.core.windows.net/raw

# %%
latest_path = f"{adls_path}/{today_file}"
print(latest_path)
# Out:
# StatementMeta(, e61dfe50-8ee3-4d61-8633-a48646002e2f, 23, Finished, Available, Finished)
# abfss://fabricproject@datalakefabriclms.dfs.core.windows.net/raw/LMS_09-02-2023.csv

# %%
from pyspark.sql.functions import lit
latest_path = f"{adls_path}/{today_file}"
df = spark.read.csv(path= latest_path,header=True,inferSchema=True)

if df.count() > 1:
    print("The file has data.")
    
    df_new = df.withColumn("Processing_Date",lit(processed_Date))
    df_new.write.format('csv').option('header','true').partitionBy('Processing_Date').mode('append').save('abfss://fabricproject@datalakefabriclms.dfs.core.windows.net/landing/')
    print("Data written to landing zone successfully !")

else:
    print('This file contains only header row and no data.')
# Out:
# StatementMeta(, e61dfe50-8ee3-4d61-8633-a48646002e2f, 24, Finished, Available, Finished)
# The file has data.
# Data written to landing zone successfully !

# %%
display(df_new)
# Out:
# StatementMeta(, e61dfe50-8ee3-4d61-8633-a48646002e2f, 26, Finished, Available, Finished)
# SynapseWidget(Synapse.DataFrame, ee8a6bfd-8631-4fcb-9c5d-ca9de80c9c36)
